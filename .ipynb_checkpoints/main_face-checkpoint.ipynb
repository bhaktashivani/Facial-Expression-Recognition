# %% [markdown]
# # ECE 285 Final Project: Facial Expression Recognition
# #### By Shivani Bhakta and Payal Singh

# %% [markdown]
# # Imports

# %%
import glob
import numpy as np
import PIL
from PIL import Image, ImageOps, ImageEnhance, ImageFilter 
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as T
import torchvision.datasets as dset
import torch.nn.functional as F
from torch.utils.data import sampler
from torch.utils.data import DataLoader, Dataset, TensorDataset

import os
import os.path as osp
import cv2 
import sys
import copy

from woodnet import *
from MyNet import *

# %% [markdown]
# ## Crop and resize images
# - We use the MTCNN face detector to recognize face in our dataset and crop each images and resize them to 224 x 224. Do this by running the PrepData.py file. Use the command ``` python PrepData.py``` in terminal
# - We then store them into a new folder
# - https://www.kaggle.com/timesler/guide-to-mtcnn-in-facenet-pytorch

# %%
USE_GPU = True

dtype = torch.float32 # we will be using float throughout this tutorial

if USE_GPU and torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

# Constant to control how frequently we print train loss
print_every = 100

print('using device:', device)
# Out:
# using device: cuda

# %% [markdown]
# ## Tufts Face DB
# In this project we use a dataset named Tufts Face Database for Facial Recognition. This dataset is made up with over 10,000 images of 74 female and 38 males from more than 15 countries with the age range between 4-70 years old. This dataset contains 7 image modalities, but we only use a subset of it, from the Tufts Face Database 2D RGB Expression (TDRGBA). This set contains 5 images of 50 different people. These 5 images are of 5 different expressions (neutral, smiling, eyes closed, surprised, and sunglasses).

# %% [markdown]
# ## Visualize the dataset

# %%
person = 1    # do not choose 47 (this participant withdrew from the dataset)
fig, axes = plt.subplots(nrows=5, ncols=2, figsize=(24, 16))

if person == 47: 
    print('Cannot display Participant 47')
for idx in np.arange(1, 6):
    # original dataset images
    orig_im = Image.open(f'dataset/{person}/TD_RGB_E_{idx}.jpg')
    # cropped dataset images
    im = Image.open(f'cropped/TD_RGB_E_{person}_{idx}.jpg')
    # Display all of the images of selected person
    axes[idx-1][0].axis('off')
    axes[idx-1][0].imshow(orig_im)
    axes[idx-1][0].set_title(f'Original dataset: person {person}, image {idx}')
    axes[idx-1][1].axis('off')
    axes[idx-1][1].imshow(im)
    axes[idx-1][1].set_title(f'Cropped dataset: person {person}, image {idx}')

# %%
def get_faces():
    '''
    input: 
        n: number of images to load from the folder. 
    output: 
        neutral_faces: numpy array with each column corresponds to a data point (each image of neutral faces) 
        smiling_faces: numpy array with each column corresponds to a data point (each image of smiling faces)
    '''
    n = 49    # number of people in dataset
    
    neutral_faces = np.zeros((n,3,224,224))
    smiling_faces = np.zeros((n,3,224,224))
    eyesclosed_faces = np.zeros((n,3,224,224))
    surprised_faces = np.zeros((n,3,224,224))
    sunglasses_faces = np.zeros((n,3,224,224))

    for i in range(1,n+1):
        if i == 47: continue
        for j in range(1,6):
            image_path = f'cropped/TD_RGB_E_{i}_{j}.jpg'
            p = Image.open(image_path)
            # this is where to do data augmentation
            p = np.transpose(np.array(p))
        
            if j == 1: neutral_faces[i-1,:] = p
            elif j == 2: smiling_faces[i-1,:] = p
            elif j ==3: eyesclosed_faces[i-1,:] = p
            elif j == 4: surprised_faces[i-1,:] = p
            elif j == 5: sunglasses_faces[i-1,:] = p

    return neutral_faces, smiling_faces, eyesclosed_faces, surprised_faces, sunglasses_faces

neutral_faces, smiling_faces, eyesclosed_faces, surprised_faces, sunglasses_faces = get_faces()
print(neutral_faces.shape)
# Out:
# (49, 3, 224, 224)

# %%
def augmentation_and_transp(p):
    
    # flip image across vertical axis
    p1 = p.transpose(PIL.Image.FLIP_LEFT_RIGHT)
    # rotate images by 5 and 10 degrees to either side
    p2 = p.rotate(5)
    p3 = p.rotate(-5)
    p4 = p.rotate(10)
    p5 = p.rotate(-10)
    # change image brightness
    enhancer = ImageEnhance.Brightness(p)
    p6 = enhancer.enhance(0.5)
    p7 = enhancer.enhance(1.5)
    # Gaussian blur images
    p8 = p.filter(ImageFilter.GaussianBlur(radius = 5))
    # translate images to left/right/up/down 
#     p9 = p.transform(p.size, Image.AFFINE, (1, 0, 5, 0, 0, 5))
#     p10 = p.transform(p.size, Image.AFFINE, (1, 0, -5, 0, 0, -5))
#     p11 = p.transform(p.size, Image.AFFINE, (1, 0, 10, 0, 0, 10))
#     p12 = p.transform(p.size, Image.AFFINE, (1, 0, -10, 0, 0, -10))
    
    p9 = p.transform(p.size, Image.AFFINE, (1, 0, 5, 0, 1, 5))
    p10 = p.transform(p.size, Image.AFFINE, (1, 0, -5, 0,1, -5))
    p11 = p.transform(p.size, Image.AFFINE, (1, 0, 10, 0, 1, 10))
    p12 = p.transform(p.size, Image.AFFINE, (1, 0, -10, 0, 1, -10))
    # normalize
    p = np.transpose(np.array(p).astype('float32')/255.0)
    p1 = np.transpose(np.array(p1).astype('float32')/255.0)
    p2 = np.transpose(np.array(p2).astype('float32')/255.0)
    p3 = np.transpose(np.array(p3).astype('float32')/255.0)
    p4 = np.transpose(np.array(p4).astype('float32')/255.0)
    p5 = np.transpose(np.array(p5).astype('float32')/255.0)
    p6 = np.transpose(np.array(p6).astype('float32')/255.0)
    p7 = np.transpose(np.array(p7).astype('float32')/255.0)
    p8 = np.transpose(np.array(p8).astype('float32')/255.0)
    p9 = np.transpose(np.array(p9).astype('float32')/255.0)
    p10 = np.transpose(np.array(p10).astype('float32')/255.0)
    p11 = np.transpose(np.array(p11).astype('float32')/255.0)
    p12 = np.transpose(np.array(p12).astype('float32')/255.0)
    
    return p, p1,  p2,  p3, p4,  p5, p6, p7, p8, p9, p10, p11, p12

def get_faces1():
    '''
    input: 
        n: number of images to load from the folder. 
    output: 
        neutral_faces: numpy array with each column corresponds to a data point (each image of neutral faces) 
        smiling_faces: numpy array with each column corresponds to a data point (each image of smiling faces)
    '''
    n = 49    # number of people in dataset
    
    neutral_faces = []
    smiling_faces = []
    eyesclosed_faces = []
    surprised_faces = []
    sunglasses_faces = []

    for i in range(1,n+1):
        if i == 47: continue
        for j in range(1,6):
            image_path = f'cropped/TD_RGB_E_{i}_{j}.jpg'
            p = Image.open(image_path)
            p, p1, p2, p3, p4, p5, p6, p7, p8, p9, p10, p11, p12 = augmentation_and_transp(p)    # data augmentation and transposing
        
            if j == 1: 
                neutral_faces.extend([p, p1, p2, p3, p4, p5, p6, p7, p8, p9, p10, p11, p12])
            elif j == 2: 
                smiling_faces.extend([p, p1, p2, p3, p4, p5, p6, p7, p8, p9, p10, p11, p12])
            elif j ==3: 
                eyesclosed_faces.extend([p, p1, p2, p3, p4, p5, p6, p7, p8, p9, p10, p11, p12])
            elif j == 4: 
                surprised_faces.extend([p, p1, p2, p3, p4, p5, p6, p7, p8, p9, p10, p11, p12])
            elif j == 5: 
                sunglasses_faces.extend([p, p1, p2, p3, p4, p5, p6, p7, p8, p9, p10, p11, p12])

    return np.array(neutral_faces), np.array(smiling_faces), np.array(eyesclosed_faces), np.array(surprised_faces), np.array(sunglasses_faces)

neutral_faces, smiling_faces, eyesclosed_faces, surprised_faces, sunglasses_faces = get_faces1()
print(np.shape(neutral_faces))
# Out:
# (624, 3, 224, 224)

# %%
# dataset
data = np.vstack((neutral_faces, smiling_faces, eyesclosed_faces, surprised_faces, sunglasses_faces))
labels_0 = [0] * len(neutral_faces)
labels_1 = [1] * len(smiling_faces)
labels_2 = [2] * len(eyesclosed_faces)
labels_3 = [3] * len(surprised_faces)
labels_4 = [4] * len(sunglasses_faces)

labels = labels_0 + labels_1 + labels_2 + labels_3 + labels_4
labels = np.array(labels)
idxs = list(range(np.shape(neutral_faces)[0]*5))
np.random.shuffle(idxs)

data = data[idxs]
labels = labels[idxs]
print("Total data shape: ", data.shape)

test_train_split = 0.88889
train_data = data[:int(test_train_split * len(idxs))]
train_labels = labels[:int(test_train_split * len(idxs))]
print("Train data shape: ", train_data.shape)

test_data = data[int(test_train_split * len(idxs)):]
test_labels = labels[int(test_train_split * len(idxs)):]
print("Test data shape: ", test_data.shape)

image = test_data[0]
image = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))
print("Individual Image size: ", image.shape)
# Out:
# Total data shape:  (3120, 3, 224, 224)
# Train data shape:  (2773, 3, 224, 224)
# Test data shape:  (347, 3, 224, 224)
# Individual Image size:  (1, 3, 224, 224)

# %%
class MyDataset(Dataset):
    ''' This class formats the dataset into a iterable-style dataset needed for the dataloader'''
    def __init__(self, data, targets, transform=None):
        self.data = data
        self.targets = targets
        self.transform = transform
        
    def __getitem__(self, index):
        x = self.data[index]
        y = self.targets[index]
        
        if self.transform:
            x = Image.fromarray(self.data[index].astype(np.uint8).transpose(1,2,0))
            x = self.transform(x)
        data = {'x': x, 'y': y}
        return data
    
    def __len__(self):
        return len(self.data)

train_data = MyDataset(train_data, train_labels)
test_data = MyDataset(test_data, test_labels)
# dataloader = DataLoader(dataset, batch_size=5)

# %% [markdown]
# # Model

# %% [markdown]
# #### Create a function to check the accuracy

# %%
NUM_TRAIN = len(train_data)
NUM_TEST = len(test_data)

def check_accuracy(loader, model):
  
    num_correct = 0
    num_samples = 0
    loss = 0.00
    model.eval()  # set model to evaluation mode
    with torch.no_grad():
        for data in loader:
            x = data['x'].to(device=device, dtype=dtype)  # move to device, e.g. GPU
            y = data['y'].to(device=device, dtype=torch.long)
            scores = model(x)
            _, preds = scores.max(1)
            num_correct += (preds == y).sum()
            num_samples += preds.size(0)
            
            loss = F.cross_entropy(scores,y) + loss
            
        acc = float(num_correct) / num_samples
        loss = loss/ num_samples
        
        print('Got %d / %d correct (%.2f)' % (num_correct, num_samples, 100 * acc))
        
        return acc, loss

# %% [markdown]
# #### Create a function for training and validation

# %%
def train_model(model, optimizer, epochs=1):
    """
    Train a model
    
    Inputs:
    - model: A PyTorch Module giving the model to train.
    - optimizer: An Optimizer object we will use to train the model
    - epochs: (Optional) A Python integer giving the number of epochs to train for
    
    Returns: Nothing, but prints model accuracies during training.
    """
    loss_arr = []
    test_loss_arr = []
    test_acc_arr =[]
    model = model.to(device=device)  # move the model parameters to CPU/GPU
  
    for e in range(epochs):
        model.train() # put model to training mode
        for t, data in enumerate(loader_train):
            x = data['x'].to(device=device, dtype=dtype)  # move to device, e.g. GPU
            y = data['y'].to(device=device, dtype=torch.long)

            scores = model(x)
            loss = F.cross_entropy(scores, y)

            # Zero out all of the gradients for the variables which the optimizer
            # will update.
            optimizer.zero_grad()

            # This is the backwards pass: compute the gradient of the loss with
            # respect to each  parameter of the model.
            loss.backward()
            
            if t == 0:
                iter_loss = loss.item()
            else:
                iter_loss = iter_loss + loss.item()

            # Actually update the parameters of the model using the gradients
            # computed by the backwards pass.
            optimizer.step()

            if t % print_every == 0:
                print(f'Epoch {e}, Iteration {t}, loss = {loss.item():.7f}')
#                 acc_Val, loss_Val = check_accuracy(loader_val, model)
#                 print()
        loss_arr.append(iter_loss/t)
    
        model.eval()
        acc_Val, loss_Val = check_accuracy(loader_test, model)
        test_loss_arr.append(loss_Val)
        test_acc_arr.append(acc_Val)
    
    # plot loss and accuracy
    f, axes = plt.subplots(2, constrained_layout=True)
    axes[0].plot(loss_arr, label="Train loss")
#     axes[0].plot(test_loss_arr, label = 'Test loss')
    axes[0].set_title('Loss History')
    axes[0].set_xlabel('Iteration')
    axes[0].set_ylabel('Loss')
    axes[0].legend(loc='upper right')
    
    axes[1].plot(test_acc_arr, label="Test accuracy")
    axes[1].set_title('Accuracy History')
    axes[1].set_xlabel('Iteration')
    axes[1].set_ylabel('Accuracy')

# %%
loader_train = DataLoader(train_data, batch_size=12, sampler=sampler.SubsetRandomSampler(range(NUM_TRAIN)))

# loader_val = DataLoader(cifar100_val, batch_size=batch_size, num_workers=2, 
#                         sampler=sampler.SubsetRandomSampler(range(NUM_TRAIN, 50000)))

# cifar100_test = dset.CIFAR100('./datasets/cifar100', train=False, download=True, 
#                             transform=transform_test)
loader_test = DataLoader(test_data, batch_size=4)

# %% [markdown]
# ## WoodNet

# %%
# define WoodNet
model = WoodNet()
optimizer = optim.Adam(model.parameters(), lr=0.0001, weight_decay=0.00001)

print_every = 10
train_model(model, optimizer, epochs=50)
# without data augmentation, test accuracy was 20/28 ~= 71.4%
# with data augmentation and normalization, test accuracy was  ~= %

# %%
# test set accuracy
check_accuracy(loader_test, model)

# %% [markdown]
# ## MyNet

# %%
# define neural network
model = MyNet()
optimizer = optim.Adam(model.parameters(), lr=0.0001, weight_decay=0.00001)
# optimizer = optim.SGD(model.parameters(), lr=0.0001, weight_decay=0.00001, momentum = 0.9, nesterov = True)
print_every = 10
train_model(model, optimizer, epochs=50)
# Out:
# Epoch 0, Iteration 0, loss = 1.6150159
# Epoch 0, Iteration 10, loss = 1.8461119
# Epoch 0, Iteration 20, loss = 1.3366994
# Epoch 0, Iteration 30, loss = 1.6494122
# Epoch 0, Iteration 40, loss = 1.0772150
# Epoch 0, Iteration 50, loss = 0.9224848
# Epoch 0, Iteration 60, loss = 0.7931768
# Epoch 0, Iteration 70, loss = 1.5854715
# Epoch 0, Iteration 80, loss = 1.1681062
# Epoch 0, Iteration 90, loss = 0.5577181
# Epoch 0, Iteration 100, loss = 0.5882533
# Epoch 0, Iteration 110, loss = 0.5516548
# Epoch 0, Iteration 120, loss = 0.7900527
# Epoch 0, Iteration 130, loss = 1.1490432
# Epoch 0, Iteration 140, loss = 0.5770770
# Epoch 0, Iteration 150, loss = 0.9118374
# Epoch 0, Iteration 160, loss = 0.7672690
# Epoch 0, Iteration 170, loss = 0.6458947
# Epoch 0, Iteration 180, loss = 0.4273450
# Epoch 0, Iteration 190, loss = 0.9283419
# Epoch 0, Iteration 200, loss = 0.5476938
# Epoch 0, Iteration 210, loss = 0.4696292
# Epoch 0, Iteration 220, loss = 0.6500270
# Epoch 0, Iteration 230, loss = 1.1468934
# Got 59 / 347 correct (17.00)
# Epoch 1, Iteration 0, loss = 0.4580849
# Epoch 1, Iteration 10, loss = 0.6785318
# Epoch 1, Iteration 20, loss = 0.2896545
# Epoch 1, Iteration 30, loss = 0.4578607
# Epoch 1, Iteration 40, loss = 0.5432671
# Epoch 1, Iteration 50, loss = 0.4134737
# Epoch 1, Iteration 60, loss = 0.9702630
# Epoch 1, Iteration 70, loss = 0.2932695
# Epoch 1, Iteration 80, loss = 0.7787458
# Epoch 1, Iteration 90, loss = 0.2226429
# Epoch 1, Iteration 100, loss = 0.3101170
# Epoch 1, Iteration 110, loss = 0.3455019
# Epoch 1, Iteration 120, loss = 0.3401197
# Epoch 1, Iteration 130, loss = 0.4777518
# Epoch 1, Iteration 140, loss = 0.3500873
# Epoch 1, Iteration 150, loss = 0.4055286
# Epoch 1, Iteration 160, loss = 0.5385372
# Epoch 1, Iteration 170, loss = 0.3015193
# Epoch 1, Iteration 180, loss = 0.8454745
# Epoch 1, Iteration 190, loss = 0.4672072
# Epoch 1, Iteration 200, loss = 0.1432328
# Epoch 1, Iteration 210, loss = 0.7008562
# Epoch 1, Iteration 220, loss = 0.5298759
# Epoch 1, Iteration 230, loss = 0.8400548
# Got 198 / 347 correct (57.06)
# Epoch 2, Iteration 0, loss = 0.3995695
# Epoch 2, Iteration 10, loss = 0.4823479
# Epoch 2, Iteration 20, loss = 0.0062155
# Epoch 2, Iteration 30, loss = 0.0482787
# Epoch 2, Iteration 40, loss = 0.0986661
# Epoch 2, Iteration 50, loss = 0.4133760
# Epoch 2, Iteration 60, loss = 0.1638937
# Epoch 2, Iteration 70, loss = 0.3163903
# Epoch 2, Iteration 80, loss = 0.2590812
# Epoch 2, Iteration 90, loss = 0.1860415
# Epoch 2, Iteration 100, loss = 0.1313240
# Epoch 2, Iteration 110, loss = 0.3408861
# Epoch 2, Iteration 120, loss = 0.3936550
# Epoch 2, Iteration 130, loss = 0.3130836
# Epoch 2, Iteration 140, loss = 0.8758157
# Epoch 2, Iteration 150, loss = 0.1453470
# Epoch 2, Iteration 160, loss = 0.6006754
# Epoch 2, Iteration 170, loss = 0.0768383
# Epoch 2, Iteration 180, loss = 0.5925839
# Epoch 2, Iteration 190, loss = 0.1651381
# Epoch 2, Iteration 200, loss = 0.2933325
# Epoch 2, Iteration 210, loss = 0.1841811
# Epoch 2, Iteration 220, loss = 0.0774623
# Epoch 2, Iteration 230, loss = 0.0512094
# Got 212 / 347 correct (61.10)
# Epoch 3, Iteration 0, loss = 0.0863014
# Epoch 3, Iteration 10, loss = 0.1014301
# Epoch 3, Iteration 20, loss = 0.1043410
# Epoch 3, Iteration 30, loss = 0.0406721
# Epoch 3, Iteration 40, loss = 0.1753394
# Epoch 3, Iteration 50, loss = 0.4942142
# Epoch 3, Iteration 60, loss = 0.1054713
# Epoch 3, Iteration 70, loss = 0.0651190
# Epoch 3, Iteration 80, loss = 0.1348320
# Epoch 3, Iteration 90, loss = 0.0639085
# Epoch 3, Iteration 100, loss = 0.0107334
# Epoch 3, Iteration 110, loss = 0.2277784
# Epoch 3, Iteration 120, loss = 0.0393002
# Epoch 3, Iteration 130, loss = 0.3167007
# Epoch 3, Iteration 140, loss = 0.2098743
# Epoch 3, Iteration 150, loss = 0.4505854
# Epoch 3, Iteration 160, loss = 0.6509238
# Epoch 3, Iteration 170, loss = 0.1714331
# Epoch 3, Iteration 180, loss = 0.0350070
# Epoch 3, Iteration 190, loss = 0.1047254
# Epoch 3, Iteration 200, loss = 0.6111546
# Epoch 3, Iteration 210, loss = 0.3095214
# Epoch 3, Iteration 220, loss = 0.0497329
# Epoch 3, Iteration 230, loss = 0.1900019
# Got 232 / 347 correct (66.86)
# Epoch 4, Iteration 0, loss = 0.0722857
# Epoch 4, Iteration 10, loss = 0.0255676
# Epoch 4, Iteration 20, loss = 0.0105579
# Epoch 4, Iteration 30, loss = 0.0148036
# Epoch 4, Iteration 40, loss = 0.2491511
# Epoch 4, Iteration 50, loss = 0.0189552
# Epoch 4, Iteration 60, loss = 0.0126779
# Epoch 4, Iteration 70, loss = 0.0550111
# Epoch 4, Iteration 80, loss = 0.0248865
# Epoch 4, Iteration 90, loss = 0.5372217
# Epoch 4, Iteration 100, loss = 0.3246397
# Epoch 4, Iteration 110, loss = 0.4329983
# Epoch 4, Iteration 120, loss = 0.0405715
# Epoch 4, Iteration 130, loss = 0.0049605
# Epoch 4, Iteration 140, loss = 0.0123701
# Epoch 4, Iteration 150, loss = 0.0666322
# Epoch 4, Iteration 160, loss = 0.0984516
# Epoch 4, Iteration 170, loss = 0.2828865
# Epoch 4, Iteration 180, loss = 0.0049435
# Epoch 4, Iteration 190, loss = 0.0688811
# Epoch 4, Iteration 200, loss = 0.0237895
# Epoch 4, Iteration 210, loss = 0.0123161
# Epoch 4, Iteration 220, loss = 0.0091025
# Epoch 4, Iteration 230, loss = 0.0166580
# Got 297 / 347 correct (85.59)
# Epoch 5, Iteration 0, loss = 0.0127411
# Epoch 5, Iteration 10, loss = 0.0050522
# Epoch 5, Iteration 20, loss = 0.1038222
# Epoch 5, Iteration 30, loss = 0.0144767
# Epoch 5, Iteration 40, loss = 0.0107966
# Epoch 5, Iteration 50, loss = 0.0137474
# Epoch 5, Iteration 60, loss = 0.0282650
# Epoch 5, Iteration 70, loss = 0.0589346
# Epoch 5, Iteration 80, loss = 0.0225795
# Epoch 5, Iteration 90, loss = 0.0060022
# Epoch 5, Iteration 100, loss = 0.0139893
# Epoch 5, Iteration 110, loss = 0.1449695
# Epoch 5, Iteration 120, loss = 0.1010210
# Epoch 5, Iteration 130, loss = 0.0306406
# Epoch 5, Iteration 140, loss = 0.0476465
# Epoch 5, Iteration 150, loss = 0.3105806
# Epoch 5, Iteration 160, loss = 0.3348630
# Epoch 5, Iteration 170, loss = 0.0045877
# Epoch 5, Iteration 180, loss = 0.0156438
# Epoch 5, Iteration 190, loss = 0.1613492
# Epoch 5, Iteration 200, loss = 1.1374394
# Epoch 5, Iteration 210, loss = 0.1495791
# Epoch 5, Iteration 220, loss = 0.0527738
# Epoch 5, Iteration 230, loss = 0.1230690
# Got 245 / 347 correct (70.61)
# Epoch 6, Iteration 0, loss = 0.1594540
# Epoch 6, Iteration 10, loss = 0.0975497
# Epoch 6, Iteration 20, loss = 0.0335086
# Epoch 6, Iteration 30, loss = 0.0676717
# Epoch 6, Iteration 40, loss = 0.0300094
# Epoch 6, Iteration 50, loss = 0.1214280
# Epoch 6, Iteration 60, loss = 0.1877389
# Epoch 6, Iteration 70, loss = 0.1444087
# Epoch 6, Iteration 80, loss = 0.1462681
# Epoch 6, Iteration 90, loss = 0.0509861
# Epoch 6, Iteration 100, loss = 0.0006423
# Epoch 6, Iteration 110, loss = 0.0337068
# Epoch 6, Iteration 120, loss = 0.0022775
# Epoch 6, Iteration 130, loss = 0.0054832
# Epoch 6, Iteration 140, loss = 0.1946594
# Epoch 6, Iteration 150, loss = 0.0813814
# Epoch 6, Iteration 160, loss = 0.0229962
# Epoch 6, Iteration 170, loss = 0.2577625
# Epoch 6, Iteration 180, loss = 0.0270978
# Epoch 6, Iteration 190, loss = 0.0021010
# Epoch 6, Iteration 200, loss = 0.0332215
# Epoch 6, Iteration 210, loss = 0.8376315
# Epoch 6, Iteration 220, loss = 0.0223320
# Epoch 6, Iteration 230, loss = 0.0000383
# Got 307 / 347 correct (88.47)
# Epoch 7, Iteration 0, loss = 0.1854044
# Epoch 7, Iteration 10, loss = 0.0015204
# Epoch 7, Iteration 20, loss = 0.0001889
# Epoch 7, Iteration 30, loss = 0.0417510
# Epoch 7, Iteration 40, loss = 0.3752679
# Epoch 7, Iteration 50, loss = 0.2149571
# Epoch 7, Iteration 60, loss = 0.0074592
# Epoch 7, Iteration 70, loss = 0.0212966
# Epoch 7, Iteration 80, loss = 0.0581993
# Epoch 7, Iteration 90, loss = 0.0019405
# Epoch 7, Iteration 100, loss = 0.1235367
# Epoch 7, Iteration 110, loss = 0.0006767
# Epoch 7, Iteration 120, loss = 0.0088451
# Epoch 7, Iteration 130, loss = 0.0048258
# Epoch 7, Iteration 140, loss = 0.0016772
# Epoch 7, Iteration 150, loss = 0.2445587
# Epoch 7, Iteration 160, loss = 0.6317786
# Epoch 7, Iteration 170, loss = 0.0534224
# Epoch 7, Iteration 180, loss = 0.0900227
# Epoch 7, Iteration 190, loss = 0.0086165
# Epoch 7, Iteration 200, loss = 0.0064692
# Epoch 7, Iteration 210, loss = 0.0015987
# Epoch 7, Iteration 220, loss = 0.0804763
# Epoch 7, Iteration 230, loss = 0.0060504
# Got 283 / 347 correct (81.56)
# Epoch 8, Iteration 0, loss = 0.0052760
# Epoch 8, Iteration 10, loss = 0.0002449
# Epoch 8, Iteration 20, loss = 0.0041484
# Epoch 8, Iteration 30, loss = 0.6507477
# Epoch 8, Iteration 40, loss = 0.0391376
# Epoch 8, Iteration 50, loss = 0.7643405
# Epoch 8, Iteration 60, loss = 0.1177828
# Epoch 8, Iteration 70, loss = 0.0769872
# Epoch 8, Iteration 80, loss = 0.0029194
# Epoch 8, Iteration 90, loss = 0.0910389
# Epoch 8, Iteration 100, loss = 0.5318698
# Epoch 8, Iteration 110, loss = 0.0086878
# Epoch 8, Iteration 120, loss = 0.0346096
# Epoch 8, Iteration 130, loss = 0.0031218
# Epoch 8, Iteration 140, loss = 0.0003986
# Epoch 8, Iteration 150, loss = 0.0378682
# Epoch 8, Iteration 160, loss = 0.0037743
# Epoch 8, Iteration 170, loss = 0.0036919
# Epoch 8, Iteration 180, loss = 0.0000074
# Epoch 8, Iteration 190, loss = 0.0042855
# Epoch 8, Iteration 200, loss = 0.3693544
# Epoch 8, Iteration 210, loss = 0.1424220
# Epoch 8, Iteration 220, loss = 0.0006406
# Epoch 8, Iteration 230, loss = 0.0081106
# Got 321 / 347 correct (92.51)
# Epoch 9, Iteration 0, loss = 0.0004941
# Epoch 9, Iteration 10, loss = 0.0106884
# Epoch 9, Iteration 20, loss = 0.0014975
# Epoch 9, Iteration 30, loss = 0.0015004
# Epoch 9, Iteration 40, loss = 0.0332894
# Epoch 9, Iteration 50, loss = 0.0812548
# Epoch 9, Iteration 60, loss = 0.5369026
# Epoch 9, Iteration 70, loss = 0.0074079
# Epoch 9, Iteration 80, loss = 0.0003226
# Epoch 9, Iteration 90, loss = 0.0050447
# Epoch 9, Iteration 100, loss = 0.0042411
# Epoch 9, Iteration 110, loss = 0.1064862
# Epoch 9, Iteration 120, loss = 0.0035482
# Epoch 9, Iteration 130, loss = 0.0038639
# Epoch 9, Iteration 140, loss = 0.0020539
# Epoch 9, Iteration 150, loss = 0.1717364
# Epoch 9, Iteration 160, loss = 0.0005691
# Epoch 9, Iteration 170, loss = 0.1123535
# Epoch 9, Iteration 180, loss = 0.0253682
# Epoch 9, Iteration 190, loss = 0.1002954
# Epoch 9, Iteration 200, loss = 0.0505787
# Epoch 9, Iteration 210, loss = 0.0048099
# Epoch 9, Iteration 220, loss = 0.0605860
# Epoch 9, Iteration 230, loss = 0.0000102
# Got 250 / 347 correct (72.05)
# Epoch 10, Iteration 0, loss = 0.0182101
# Epoch 10, Iteration 10, loss = 0.0013467
# Epoch 10, Iteration 20, loss = 0.0278604
# Epoch 10, Iteration 30, loss = 0.0015809
# Epoch 10, Iteration 40, loss = 0.0000464
# Epoch 10, Iteration 50, loss = 0.0022840
# Epoch 10, Iteration 60, loss = 0.0260834
# Epoch 10, Iteration 70, loss = 0.0069670
# Epoch 10, Iteration 80, loss = 0.0012294
# Epoch 10, Iteration 90, loss = 0.0488779
# Epoch 10, Iteration 100, loss = 0.0207323
# Epoch 10, Iteration 110, loss = 0.0002441
# Epoch 10, Iteration 120, loss = 0.0324290
# Epoch 10, Iteration 130, loss = 0.0840606
# Epoch 10, Iteration 140, loss = 0.0275509
# Epoch 10, Iteration 150, loss = 0.0743311
# Epoch 10, Iteration 160, loss = 0.0142422
# Epoch 10, Iteration 170, loss = 0.0086983
# Epoch 10, Iteration 180, loss = 0.0007077
# Epoch 10, Iteration 190, loss = 0.1301223
# Epoch 10, Iteration 200, loss = 0.0006824
# Epoch 10, Iteration 210, loss = 0.3007939
# Epoch 10, Iteration 220, loss = 0.0014842
# Epoch 10, Iteration 230, loss = 0.0093263
# Got 309 / 347 correct (89.05)
# Epoch 11, Iteration 0, loss = 0.0018283
# Epoch 11, Iteration 10, loss = 0.0003713
# Epoch 11, Iteration 20, loss = 0.0108828
# Epoch 11, Iteration 30, loss = 0.0023697
# Epoch 11, Iteration 40, loss = 0.0031329
# Epoch 11, Iteration 50, loss = 0.0012951
# Epoch 11, Iteration 60, loss = 0.0001455
# Epoch 11, Iteration 70, loss = 0.0008752
# Epoch 11, Iteration 80, loss = 0.0066471
# Epoch 11, Iteration 90, loss = 0.0005109
# Epoch 11, Iteration 100, loss = 0.1606449
# Epoch 11, Iteration 110, loss = 0.0482814
# Epoch 11, Iteration 120, loss = 0.0263605
# Epoch 11, Iteration 130, loss = 0.0152228
# Epoch 11, Iteration 140, loss = 0.0000050
# Epoch 11, Iteration 150, loss = 0.0238030
# Epoch 11, Iteration 160, loss = 0.0001089
# Epoch 11, Iteration 170, loss = 0.0456501
# Epoch 11, Iteration 180, loss = 0.0000901
# Epoch 11, Iteration 190, loss = 0.0000017
# Epoch 11, Iteration 200, loss = 0.4570183
# Epoch 11, Iteration 210, loss = 0.0000014
# Epoch 11, Iteration 220, loss = 0.0002840
# Epoch 11, Iteration 230, loss = 0.0052761
# Got 309 / 347 correct (89.05)
# Epoch 12, Iteration 0, loss = 0.0011338
# Epoch 12, Iteration 10, loss = 0.0138893
# Epoch 12, Iteration 20, loss = 0.0003366
# Epoch 12, Iteration 30, loss = 0.0152265
# Epoch 12, Iteration 40, loss = 0.0330042
# Epoch 12, Iteration 50, loss = 0.0002774
# Epoch 12, Iteration 60, loss = 0.0086694
# Epoch 12, Iteration 70, loss = 0.0040825
# Epoch 12, Iteration 80, loss = 0.1239660
# Epoch 12, Iteration 90, loss = 0.0004484
# Epoch 12, Iteration 100, loss = 0.0267442
# Epoch 12, Iteration 110, loss = 0.0000331
# Epoch 12, Iteration 120, loss = 0.0020970
# Epoch 12, Iteration 130, loss = 0.0275692
# Epoch 12, Iteration 140, loss = 0.0585434
# Epoch 12, Iteration 150, loss = 0.1227931
# Epoch 12, Iteration 160, loss = 0.0050960
# Epoch 12, Iteration 170, loss = 0.0148027
# Epoch 12, Iteration 180, loss = 0.0632781
# Epoch 12, Iteration 190, loss = 0.0000544
# Epoch 12, Iteration 200, loss = 0.0007038
# Epoch 12, Iteration 210, loss = 0.0001647
# Epoch 12, Iteration 220, loss = 0.0076352
# Epoch 12, Iteration 230, loss = 0.2198178
# Got 322 / 347 correct (92.80)
# Epoch 13, Iteration 0, loss = 0.0000137
# Epoch 13, Iteration 10, loss = 0.0003762
# Epoch 13, Iteration 20, loss = 0.0001805
# Epoch 13, Iteration 30, loss = 0.0908294
# Epoch 13, Iteration 40, loss = 0.0056262
# Epoch 13, Iteration 50, loss = 0.0023091
# Epoch 13, Iteration 60, loss = 0.0000907
# Epoch 13, Iteration 70, loss = 0.0143454
# Epoch 13, Iteration 80, loss = 0.2716362
# Epoch 13, Iteration 90, loss = 0.0155169
# Epoch 13, Iteration 100, loss = 0.3967859
# Epoch 13, Iteration 110, loss = 0.0107393
# Epoch 13, Iteration 120, loss = 0.0009150
# Epoch 13, Iteration 130, loss = 0.0650152
# Epoch 13, Iteration 140, loss = 0.0017707
# Epoch 13, Iteration 150, loss = 0.0127899
# Epoch 13, Iteration 160, loss = 0.0008841
# Epoch 13, Iteration 170, loss = 0.0326292
# Epoch 13, Iteration 180, loss = 0.0350718
# Epoch 13, Iteration 190, loss = 0.0025429
# Epoch 13, Iteration 200, loss = 0.0577087
# Epoch 13, Iteration 210, loss = 0.0175342
# Epoch 13, Iteration 220, loss = 0.0000587
# Epoch 13, Iteration 230, loss = 0.0591949
# Got 291 / 347 correct (83.86)
# Epoch 14, Iteration 0, loss = 0.0411951
# Epoch 14, Iteration 10, loss = 0.2870382
# Epoch 14, Iteration 20, loss = 0.0000271
# Epoch 14, Iteration 30, loss = 0.4950352
# Epoch 14, Iteration 40, loss = 0.0006616
# Epoch 14, Iteration 50, loss = 0.0007931
# Epoch 14, Iteration 60, loss = 0.0205133
# Epoch 14, Iteration 70, loss = 0.0001971
# Epoch 14, Iteration 80, loss = 0.0000235
# Epoch 14, Iteration 90, loss = 0.0002236
# Epoch 14, Iteration 100, loss = 0.0000012
# Epoch 14, Iteration 110, loss = 0.0000147
# Epoch 14, Iteration 120, loss = 0.0000002
# Epoch 14, Iteration 130, loss = 0.0006153
# Epoch 14, Iteration 140, loss = 0.0000589
# Epoch 14, Iteration 150, loss = 0.0003687
# Epoch 14, Iteration 160, loss = 0.0005322
# Epoch 14, Iteration 170, loss = 0.0001894
# Epoch 14, Iteration 180, loss = 0.0000261
# Epoch 14, Iteration 190, loss = 0.0015482
# Epoch 14, Iteration 200, loss = 0.0011150
# Epoch 14, Iteration 210, loss = 0.0001879
# Epoch 14, Iteration 220, loss = 0.0000286
# Epoch 14, Iteration 230, loss = 0.0000699
# Got 285 / 347 correct (82.13)
# Epoch 15, Iteration 0, loss = 0.0000024
# Epoch 15, Iteration 10, loss = 0.0002172
# Epoch 15, Iteration 20, loss = 0.0000596
# Epoch 15, Iteration 30, loss = 0.0737652
# Epoch 15, Iteration 40, loss = 0.0169012
# Epoch 15, Iteration 50, loss = 0.1311958
# Epoch 15, Iteration 60, loss = 0.0001510
# Epoch 15, Iteration 70, loss = 0.0000091
# Epoch 15, Iteration 80, loss = 0.0311809
# Epoch 15, Iteration 90, loss = 0.0015667
# Epoch 15, Iteration 100, loss = 0.0000968
# Epoch 15, Iteration 110, loss = 0.0000025
# Epoch 15, Iteration 120, loss = 0.0098945
# Epoch 15, Iteration 130, loss = 0.1423650
# Epoch 15, Iteration 140, loss = 0.0195086
# Epoch 15, Iteration 150, loss = 0.0033223
# Epoch 15, Iteration 160, loss = 0.4506236
# Epoch 15, Iteration 170, loss = 0.1170763
# Epoch 15, Iteration 180, loss = 1.0195682
# Epoch 15, Iteration 190, loss = 0.0015600
# Epoch 15, Iteration 200, loss = 0.0001892
# Epoch 15, Iteration 210, loss = 0.0003044
# Epoch 15, Iteration 220, loss = 0.1101826
# Epoch 15, Iteration 230, loss = 0.1191524
# Got 314 / 347 correct (90.49)
# Epoch 16, Iteration 0, loss = 0.0000768
# Epoch 16, Iteration 10, loss = 0.0004043
# Epoch 16, Iteration 20, loss = 0.3350616
# Epoch 16, Iteration 30, loss = 0.0011352
# Epoch 16, Iteration 40, loss = 0.0004867
# Epoch 16, Iteration 50, loss = 0.0006787
# Epoch 16, Iteration 60, loss = 0.0417950
# Epoch 16, Iteration 70, loss = 0.0541132
# Epoch 16, Iteration 80, loss = 0.0032475
# Epoch 16, Iteration 90, loss = 0.0000002
# Epoch 16, Iteration 100, loss = 0.0000889
# Epoch 16, Iteration 110, loss = 0.0000054
# Epoch 16, Iteration 120, loss = 0.0586518
# Epoch 16, Iteration 130, loss = 0.0530288
# Epoch 16, Iteration 140, loss = 0.5134736
# Epoch 16, Iteration 150, loss = 0.0000183
# Epoch 16, Iteration 160, loss = 0.0000318
# Epoch 16, Iteration 170, loss = 0.0005462
# Epoch 16, Iteration 180, loss = 0.0008686
# Epoch 16, Iteration 190, loss = 0.0006042
# Epoch 16, Iteration 200, loss = 0.3358474
# Epoch 16, Iteration 210, loss = 0.0088882
# Epoch 16, Iteration 220, loss = 0.1234046
# Epoch 16, Iteration 230, loss = 0.1096794
# Got 275 / 347 correct (79.25)
# Epoch 17, Iteration 0, loss = 0.0000861
# Epoch 17, Iteration 10, loss = 0.0000951
# Epoch 17, Iteration 20, loss = 0.1484298
# Epoch 17, Iteration 30, loss = 0.0007555
# Epoch 17, Iteration 40, loss = 0.0079830
# Epoch 17, Iteration 50, loss = 0.0024037
# Epoch 17, Iteration 60, loss = 0.0000055
# Epoch 17, Iteration 70, loss = 0.0023936
# Epoch 17, Iteration 80, loss = 0.0002865
# Epoch 17, Iteration 90, loss = 0.0946141
# Epoch 17, Iteration 100, loss = 0.0004599
# Epoch 17, Iteration 110, loss = 0.0001523
# Epoch 17, Iteration 120, loss = 0.0000045
# Epoch 17, Iteration 130, loss = 0.0001844
# Epoch 17, Iteration 140, loss = 0.0019380
# Epoch 17, Iteration 150, loss = 0.0031809
# Epoch 17, Iteration 160, loss = 0.0003706
# Epoch 17, Iteration 170, loss = 0.0004207
# Epoch 17, Iteration 180, loss = 0.0004704
# Epoch 17, Iteration 190, loss = 0.0000713
# Epoch 17, Iteration 200, loss = 0.0003616
# Epoch 17, Iteration 210, loss = 0.0000720
# Epoch 17, Iteration 220, loss = 0.0304582
# Epoch 17, Iteration 230, loss = 0.0028387
# Got 302 / 347 correct (87.03)
# Epoch 18, Iteration 0, loss = 0.3081838
# Epoch 18, Iteration 10, loss = 0.0000011
# Epoch 18, Iteration 20, loss = 0.0005224
# Epoch 18, Iteration 30, loss = 0.0865320
# Epoch 18, Iteration 40, loss = 0.0006491
# Epoch 18, Iteration 50, loss = 0.0040589
# Epoch 18, Iteration 60, loss = 0.0000077
# Epoch 18, Iteration 70, loss = 0.0000999
# Epoch 18, Iteration 80, loss = 0.0007590
# Epoch 18, Iteration 90, loss = 0.0000089
# Epoch 18, Iteration 100, loss = 0.4534268
# Epoch 18, Iteration 110, loss = 0.0026366
# Epoch 18, Iteration 120, loss = 0.0012937
# Epoch 18, Iteration 130, loss = 0.2579187
# Epoch 18, Iteration 140, loss = 0.0023702
# Epoch 18, Iteration 150, loss = 0.0005812
# Epoch 18, Iteration 160, loss = 0.0003327
# Epoch 18, Iteration 170, loss = 0.0001953
# Epoch 18, Iteration 180, loss = 0.0003954
# Epoch 18, Iteration 190, loss = 0.0000595
# Epoch 18, Iteration 200, loss = 0.0001173
# Epoch 18, Iteration 210, loss = 0.0000115
# Epoch 18, Iteration 220, loss = 0.0078297
# Epoch 18, Iteration 230, loss = 0.2315336
# Got 337 / 347 correct (97.12)
# Epoch 19, Iteration 0, loss = 0.1046144
# Epoch 19, Iteration 10, loss = 0.0005296
# Epoch 19, Iteration 20, loss = 0.0001086
# Epoch 19, Iteration 30, loss = 0.0034085
# Epoch 19, Iteration 40, loss = 0.0000233
# Epoch 19, Iteration 50, loss = 0.0002500
# Epoch 19, Iteration 60, loss = 0.0013299
# Epoch 19, Iteration 70, loss = 0.0003671
# Epoch 19, Iteration 80, loss = 0.0078808
# Epoch 19, Iteration 90, loss = 0.0000880
# Epoch 19, Iteration 100, loss = 0.0150839
# Epoch 19, Iteration 110, loss = 0.0000184
# Epoch 19, Iteration 120, loss = 0.0000028
# Epoch 19, Iteration 130, loss = 0.0000003
# Epoch 19, Iteration 140, loss = 0.0003532
# Epoch 19, Iteration 150, loss = 0.0001520
# Epoch 19, Iteration 160, loss = 0.0001070
# Epoch 19, Iteration 170, loss = 0.0412635
# Epoch 19, Iteration 180, loss = 0.0000001
# Epoch 19, Iteration 190, loss = 0.0062172
# Epoch 19, Iteration 200, loss = 0.0000706
# Epoch 19, Iteration 210, loss = 0.0000009
# Epoch 19, Iteration 220, loss = 0.0135803
# Epoch 19, Iteration 230, loss = 0.0019281
# Got 324 / 347 correct (93.37)
# Epoch 20, Iteration 0, loss = 0.0000192
# Epoch 20, Iteration 10, loss = 0.0001517
# Epoch 20, Iteration 20, loss = 0.0000106
# Epoch 20, Iteration 30, loss = 0.0001631
# Epoch 20, Iteration 40, loss = 0.0000770
# Epoch 20, Iteration 50, loss = 0.0153697
# Epoch 20, Iteration 60, loss = 0.4228311
# Epoch 20, Iteration 70, loss = 0.0043944
# Epoch 20, Iteration 80, loss = 0.0000004
# Epoch 20, Iteration 90, loss = 0.0005620
# Epoch 20, Iteration 100, loss = 0.0360387
# Epoch 20, Iteration 110, loss = 0.4491477
# Epoch 20, Iteration 120, loss = 0.1437005
# Epoch 20, Iteration 130, loss = 0.2848670
# Epoch 20, Iteration 140, loss = 0.0000705
# Epoch 20, Iteration 150, loss = 0.0163549
# Epoch 20, Iteration 160, loss = 0.0001062
# Epoch 20, Iteration 170, loss = 0.2655681
# Epoch 20, Iteration 180, loss = 0.0037013
# Epoch 20, Iteration 190, loss = 0.0009760
# Epoch 20, Iteration 200, loss = 0.0000238
# Epoch 20, Iteration 210, loss = 0.0030358
# Epoch 20, Iteration 220, loss = 0.0017305
# Epoch 20, Iteration 230, loss = 0.0005143
# Got 321 / 347 correct (92.51)
# Epoch 21, Iteration 0, loss = 0.0000005
# Epoch 21, Iteration 10, loss = 0.0640250
# Epoch 21, Iteration 20, loss = 0.0035090
# Epoch 21, Iteration 30, loss = 0.0008763
# Epoch 21, Iteration 40, loss = 0.0004348
# Epoch 21, Iteration 50, loss = 0.0002799
# Epoch 21, Iteration 60, loss = 0.0003983
# Epoch 21, Iteration 70, loss = 0.0000064
# Epoch 21, Iteration 80, loss = 0.0001401
# Epoch 21, Iteration 90, loss = 0.0000001
# Epoch 21, Iteration 100, loss = 0.0031233
# Epoch 21, Iteration 110, loss = 0.0016055
# Epoch 21, Iteration 120, loss = 0.0025846
# Epoch 21, Iteration 130, loss = 0.0005404
# Epoch 21, Iteration 140, loss = 0.0126626
# Epoch 21, Iteration 150, loss = 0.0059896
# Epoch 21, Iteration 160, loss = 0.0000003
# Epoch 21, Iteration 170, loss = 0.0005953
# Epoch 21, Iteration 180, loss = 0.0000028
# Epoch 21, Iteration 190, loss = 0.0000068
# Epoch 21, Iteration 200, loss = 0.0001250
# Epoch 21, Iteration 210, loss = 0.0000011
# Epoch 21, Iteration 220, loss = 0.0002906
# Epoch 21, Iteration 230, loss = 0.0000089
# Got 300 / 347 correct (86.46)
# Epoch 22, Iteration 0, loss = 0.0016795
# Epoch 22, Iteration 10, loss = 0.0000605
# Epoch 22, Iteration 20, loss = 0.0009717
# Epoch 22, Iteration 30, loss = 0.0016175
# Epoch 22, Iteration 40, loss = 0.0000468
# Epoch 22, Iteration 50, loss = 0.0104798
# Epoch 22, Iteration 60, loss = 0.0002233
# Epoch 22, Iteration 70, loss = 0.0000006
# Epoch 22, Iteration 80, loss = 0.0000885
# Epoch 22, Iteration 90, loss = 0.0014011
# Epoch 22, Iteration 100, loss = 0.2859862
# Epoch 22, Iteration 110, loss = 0.1088709
# Epoch 22, Iteration 120, loss = 0.0000007
# Epoch 22, Iteration 130, loss = 0.0188469
# Epoch 22, Iteration 140, loss = 0.0000010
# Epoch 22, Iteration 150, loss = 0.0000014
# Epoch 22, Iteration 160, loss = 0.0096899
# Epoch 22, Iteration 170, loss = 0.0000498
# Epoch 22, Iteration 180, loss = 0.0000269
# Epoch 22, Iteration 190, loss = 0.0000000
# Epoch 22, Iteration 200, loss = 0.0000825
# Epoch 22, Iteration 210, loss = 0.0010425
# Epoch 22, Iteration 220, loss = 0.0379471
# Epoch 22, Iteration 230, loss = 0.0000101
# Got 341 / 347 correct (98.27)
# Epoch 23, Iteration 0, loss = 0.0000001
# Epoch 23, Iteration 10, loss = 0.0003202
# Epoch 23, Iteration 20, loss = 0.0000335
# Epoch 23, Iteration 30, loss = 0.0000447
# Epoch 23, Iteration 40, loss = 0.0034478
# Epoch 23, Iteration 50, loss = 0.0000037
# Epoch 23, Iteration 60, loss = 0.0044521
# Epoch 23, Iteration 70, loss = 0.0013761
# Epoch 23, Iteration 80, loss = 0.0117635
# Epoch 23, Iteration 90, loss = 0.0098135
# Epoch 23, Iteration 100, loss = 0.0570803
# Epoch 23, Iteration 110, loss = 0.0337787
# Epoch 23, Iteration 120, loss = 0.0007309
# Epoch 23, Iteration 130, loss = 0.0765827
# Epoch 23, Iteration 140, loss = 0.0014626
# Epoch 23, Iteration 150, loss = 0.0047062
# Epoch 23, Iteration 160, loss = 0.0000035
# Epoch 23, Iteration 170, loss = 0.0000075
# Epoch 23, Iteration 180, loss = 0.0000492
# Epoch 23, Iteration 190, loss = 0.0001618
# Epoch 23, Iteration 200, loss = 0.1386010
# Epoch 23, Iteration 210, loss = 0.0007192
# Epoch 23, Iteration 220, loss = 0.0000001
# Epoch 23, Iteration 230, loss = 0.0006485
# Got 335 / 347 correct (96.54)
# Epoch 24, Iteration 0, loss = 0.0127842
# Epoch 24, Iteration 10, loss = 0.0000988
# Epoch 24, Iteration 20, loss = 0.1637456
# Epoch 24, Iteration 30, loss = 0.0013858
# Epoch 24, Iteration 40, loss = 0.0016172
# Epoch 24, Iteration 50, loss = 0.0019593
# Epoch 24, Iteration 60, loss = 0.0003294
# Epoch 24, Iteration 70, loss = 0.0134825
# Epoch 24, Iteration 80, loss = 0.0000273
# Epoch 24, Iteration 90, loss = 0.0038458
# Epoch 24, Iteration 100, loss = 0.0010408
# Epoch 24, Iteration 110, loss = 0.0472289
# Epoch 24, Iteration 120, loss = 0.0000118
# Epoch 24, Iteration 130, loss = 0.0000110
# Epoch 24, Iteration 140, loss = 0.0088181
# Epoch 24, Iteration 150, loss = 0.0000518
# Epoch 24, Iteration 160, loss = 0.0084182
# Epoch 24, Iteration 170, loss = 0.0017932
# Epoch 24, Iteration 180, loss = 0.0136805
# Epoch 24, Iteration 190, loss = 0.0245216
# Epoch 24, Iteration 200, loss = 0.0024866
# Epoch 24, Iteration 210, loss = 0.0000130
# Epoch 24, Iteration 220, loss = 0.0000730
# Epoch 24, Iteration 230, loss = 0.0000584
# Got 315 / 347 correct (90.78)
# Epoch 25, Iteration 0, loss = 0.0000448
# Epoch 25, Iteration 10, loss = 0.0002089
# Epoch 25, Iteration 20, loss = 0.0000261
# Epoch 25, Iteration 30, loss = 0.0006729
# Epoch 25, Iteration 40, loss = 0.0201620
# Epoch 25, Iteration 50, loss = 0.0000331
# Epoch 25, Iteration 60, loss = 0.0060376
# Epoch 25, Iteration 70, loss = 0.0000116
# Epoch 25, Iteration 80, loss = 0.0000000
# Epoch 25, Iteration 90, loss = 0.0000691
# Epoch 25, Iteration 100, loss = 0.0008206
# Epoch 25, Iteration 110, loss = 0.0000266
# Epoch 25, Iteration 120, loss = 0.0000144
# Epoch 25, Iteration 130, loss = 0.0000002
# Epoch 25, Iteration 140, loss = 0.0006618
# Epoch 25, Iteration 150, loss = 0.0000126
# Epoch 25, Iteration 160, loss = 0.0000269
# Epoch 25, Iteration 170, loss = 0.0410825
# Epoch 25, Iteration 180, loss = 0.0000295
# Epoch 25, Iteration 190, loss = 0.0046024
# Epoch 25, Iteration 200, loss = 0.0072799
# Epoch 25, Iteration 210, loss = 0.0403515
# Epoch 25, Iteration 220, loss = 0.0002110
# Epoch 25, Iteration 230, loss = 0.0001346
# Got 327 / 347 correct (94.24)
# Epoch 26, Iteration 0, loss = 0.0000061
# Epoch 26, Iteration 10, loss = 0.0002444
# Epoch 26, Iteration 20, loss = 0.0000000
# Epoch 26, Iteration 30, loss = 0.0002849
# Epoch 26, Iteration 40, loss = 0.0006675
# Epoch 26, Iteration 50, loss = 0.0000234
# Epoch 26, Iteration 60, loss = 0.0000416
# Epoch 26, Iteration 70, loss = 0.0065941
# Epoch 26, Iteration 80, loss = 0.0001986
# Epoch 26, Iteration 90, loss = 0.0003439
# Epoch 26, Iteration 100, loss = 0.0000877
# Epoch 26, Iteration 110, loss = 0.0000420
# Epoch 26, Iteration 120, loss = 0.0002480
# Epoch 26, Iteration 130, loss = 0.4600418
# Epoch 26, Iteration 140, loss = 0.0063172
# Epoch 26, Iteration 150, loss = 0.0227631
# Epoch 26, Iteration 160, loss = 0.0000122
# Epoch 26, Iteration 170, loss = 0.0000848
# Epoch 26, Iteration 180, loss = 0.2067726
# Epoch 26, Iteration 190, loss = 0.0011514
# Epoch 26, Iteration 200, loss = 0.0000003
# Epoch 26, Iteration 210, loss = 0.0002312
# Epoch 26, Iteration 220, loss = 0.0098652
# Epoch 26, Iteration 230, loss = 0.0643540
# Got 327 / 347 correct (94.24)
# Epoch 27, Iteration 0, loss = 0.0000990
# Epoch 27, Iteration 10, loss = 0.0003892
# Epoch 27, Iteration 20, loss = 0.0000589
# Epoch 27, Iteration 30, loss = 0.0000317
# Epoch 27, Iteration 40, loss = 0.0063843
# Epoch 27, Iteration 50, loss = 0.0000019
# Epoch 27, Iteration 60, loss = 0.0005743
# Epoch 27, Iteration 70, loss = 0.0062775
# Epoch 27, Iteration 80, loss = 0.1791034
# Epoch 27, Iteration 90, loss = 0.0039443
# Epoch 27, Iteration 100, loss = 0.0048683
# Epoch 27, Iteration 110, loss = 0.0000458
# Epoch 27, Iteration 120, loss = 0.0061338
# Epoch 27, Iteration 130, loss = 0.0049197
# Epoch 27, Iteration 140, loss = 0.0001129
# Epoch 27, Iteration 150, loss = 0.0000126
# Epoch 27, Iteration 160, loss = 0.0041389
# Epoch 27, Iteration 170, loss = 0.0000171
# Epoch 27, Iteration 180, loss = 0.0044226
# Epoch 27, Iteration 190, loss = 0.3220354
# Epoch 27, Iteration 200, loss = 0.0000000
# Epoch 27, Iteration 210, loss = 0.0001634
# Epoch 27, Iteration 220, loss = 0.0001570
# Epoch 27, Iteration 230, loss = 0.0000535
# Got 323 / 347 correct (93.08)
# Epoch 28, Iteration 0, loss = 0.0006170
# Epoch 28, Iteration 10, loss = 0.2890703
# Epoch 28, Iteration 20, loss = 0.0007976
# Epoch 28, Iteration 30, loss = 0.0000000
# Epoch 28, Iteration 40, loss = 0.1036519
# Epoch 28, Iteration 50, loss = 0.0000351
# Epoch 28, Iteration 60, loss = 0.0009048
# Epoch 28, Iteration 70, loss = 0.0043950
# Epoch 28, Iteration 80, loss = 0.0000025
# Epoch 28, Iteration 90, loss = 0.0003399
# Epoch 28, Iteration 100, loss = 0.0000180
# Epoch 28, Iteration 110, loss = 0.0081064
# Epoch 28, Iteration 120, loss = 0.0029103
# Epoch 28, Iteration 130, loss = 0.0000000
# Epoch 28, Iteration 140, loss = 0.0000006
# Epoch 28, Iteration 150, loss = 0.0000011
# Epoch 28, Iteration 160, loss = 0.0000001
# Epoch 28, Iteration 170, loss = 0.0000254
# Epoch 28, Iteration 180, loss = 0.0003185
# Epoch 28, Iteration 190, loss = 0.0000160
# Epoch 28, Iteration 200, loss = 0.0000006
# Epoch 28, Iteration 210, loss = 0.0001372
# Epoch 28, Iteration 220, loss = 0.0000000
# Epoch 28, Iteration 230, loss = 0.0000685
# Got 336 / 347 correct (96.83)
# Epoch 29, Iteration 0, loss = 0.0129893
# Epoch 29, Iteration 10, loss = 0.0000018
# Epoch 29, Iteration 20, loss = 0.0000001
# Epoch 29, Iteration 30, loss = 0.2096132
# Epoch 29, Iteration 40, loss = 0.0000056
# Epoch 29, Iteration 50, loss = 0.0000023
# Epoch 29, Iteration 60, loss = 0.0025339
# Epoch 29, Iteration 70, loss = 0.0332313
# Epoch 29, Iteration 80, loss = 0.0000413
# Epoch 29, Iteration 90, loss = 0.0000048
# Epoch 29, Iteration 100, loss = 0.2622981
# Epoch 29, Iteration 110, loss = 1.0275595
# Epoch 29, Iteration 120, loss = 0.0000033
# Epoch 29, Iteration 130, loss = 0.0048441
# Epoch 29, Iteration 140, loss = 0.0000003
# Epoch 29, Iteration 150, loss = 0.0040574
# Epoch 29, Iteration 160, loss = 0.0037293
# Epoch 29, Iteration 170, loss = 0.0100639
# Epoch 29, Iteration 180, loss = 0.0003404
# Epoch 29, Iteration 190, loss = 0.0056395
# Epoch 29, Iteration 200, loss = 0.0000279
# Epoch 29, Iteration 210, loss = 0.0038731
# Epoch 29, Iteration 220, loss = 0.0002276
# Epoch 29, Iteration 230, loss = 0.0000236
# Got 337 / 347 correct (97.12)
# Epoch 30, Iteration 0, loss = 0.0092640
# Epoch 30, Iteration 10, loss = 0.0000205
# Epoch 30, Iteration 20, loss = 0.0000014
# Epoch 30, Iteration 30, loss = 0.0058550
# Epoch 30, Iteration 40, loss = 0.0000006
# Epoch 30, Iteration 50, loss = 0.0000068
# Epoch 30, Iteration 60, loss = 0.0112885
# Epoch 30, Iteration 70, loss = 0.0000002
# Epoch 30, Iteration 80, loss = 0.0001369
# Epoch 30, Iteration 90, loss = 0.0000734
# Epoch 30, Iteration 100, loss = 0.0000045
# Epoch 30, Iteration 110, loss = 0.0270346
# Epoch 30, Iteration 120, loss = 0.0000014
# Epoch 30, Iteration 130, loss = 0.0000027
# Epoch 30, Iteration 140, loss = 0.0001578
# Epoch 30, Iteration 150, loss = 0.0093040
# Epoch 30, Iteration 160, loss = 0.0000110
# Epoch 30, Iteration 170, loss = 0.0000716
# Epoch 30, Iteration 180, loss = 0.0002650
# Epoch 30, Iteration 190, loss = 0.0002937
# Epoch 30, Iteration 200, loss = 0.0000213
# Epoch 30, Iteration 210, loss = 0.0038600
# Epoch 30, Iteration 220, loss = 0.0000037
# Epoch 30, Iteration 230, loss = 0.0206870
# Got 308 / 347 correct (88.76)
# Epoch 31, Iteration 0, loss = 0.0006235
# Epoch 31, Iteration 10, loss = 0.0000315
# Epoch 31, Iteration 20, loss = 0.0003184
# Epoch 31, Iteration 30, loss = 0.0004453
# Epoch 31, Iteration 40, loss = 0.1899672
# Epoch 31, Iteration 50, loss = 0.5119643
# Epoch 31, Iteration 60, loss = 0.0000249
# Epoch 31, Iteration 70, loss = 0.0000001
# Epoch 31, Iteration 80, loss = 0.0041292
# Epoch 31, Iteration 90, loss = 0.0599665
# Epoch 31, Iteration 100, loss = 0.0000055
# Epoch 31, Iteration 110, loss = 0.0000211
# Epoch 31, Iteration 120, loss = 0.0006212
# Epoch 31, Iteration 130, loss = 0.0416134
# Epoch 31, Iteration 140, loss = 0.1402317
# Epoch 31, Iteration 150, loss = 0.0008469
# Epoch 31, Iteration 160, loss = 0.0000173
# Epoch 31, Iteration 170, loss = 0.0004416
# Epoch 31, Iteration 180, loss = 0.1164216
# Epoch 31, Iteration 190, loss = 0.0000553
# Epoch 31, Iteration 200, loss = 0.0000573
# Epoch 31, Iteration 210, loss = 0.0000007
# Epoch 31, Iteration 220, loss = 0.0041920
# Epoch 31, Iteration 230, loss = 0.0000405
# Got 322 / 347 correct (92.80)
# Epoch 32, Iteration 0, loss = 0.0122907
# Epoch 32, Iteration 10, loss = 0.0037664
# Epoch 32, Iteration 20, loss = 0.0000615
# Epoch 32, Iteration 30, loss = 0.0006471
# Epoch 32, Iteration 40, loss = 0.0003969
# Epoch 32, Iteration 50, loss = 0.0044816
# Epoch 32, Iteration 60, loss = 0.0000486
# Epoch 32, Iteration 70, loss = 0.0445026
# Epoch 32, Iteration 80, loss = 0.0000001
# Epoch 32, Iteration 90, loss = 0.0093249
# Epoch 32, Iteration 100, loss = 0.0000600
# Epoch 32, Iteration 110, loss = 0.0004378
# Epoch 32, Iteration 120, loss = 0.0000127
# Epoch 32, Iteration 130, loss = 0.0028334
# Epoch 32, Iteration 140, loss = 0.0048185
# Epoch 32, Iteration 150, loss = 0.0001829
# Epoch 32, Iteration 160, loss = 0.0000525
# Epoch 32, Iteration 170, loss = 0.0000375
# Epoch 32, Iteration 180, loss = 0.0031697
# Epoch 32, Iteration 190, loss = 0.0000000
# Epoch 32, Iteration 200, loss = 0.0000044
# Epoch 32, Iteration 210, loss = 0.0000606
# Epoch 32, Iteration 220, loss = 0.0000173
# Epoch 32, Iteration 230, loss = 0.0000575
# Got 338 / 347 correct (97.41)
# Epoch 33, Iteration 0, loss = 0.0002707
# Epoch 33, Iteration 10, loss = 0.0004228
# Epoch 33, Iteration 20, loss = 0.0002101
# Epoch 33, Iteration 30, loss = 0.0121564
# Epoch 33, Iteration 40, loss = 0.0000214
# Epoch 33, Iteration 50, loss = 0.0000016
# Epoch 33, Iteration 60, loss = 0.0000850
# Epoch 33, Iteration 70, loss = 0.0042789
# Epoch 33, Iteration 80, loss = 0.0000360
# Epoch 33, Iteration 90, loss = 0.0000695
# Epoch 33, Iteration 100, loss = 0.0000005
# Epoch 33, Iteration 110, loss = 0.0000013
# Epoch 33, Iteration 120, loss = 0.0000958
# Epoch 33, Iteration 130, loss = 0.0000004
# Epoch 33, Iteration 140, loss = 0.0143354
# Epoch 33, Iteration 150, loss = 0.0211537
# Epoch 33, Iteration 160, loss = 0.0007417
# Epoch 33, Iteration 170, loss = 0.0000345
# Epoch 33, Iteration 180, loss = 0.0001295
# Epoch 33, Iteration 190, loss = 0.0000000
# Epoch 33, Iteration 200, loss = 0.0000306
# Epoch 33, Iteration 210, loss = 0.0000000
# Epoch 33, Iteration 220, loss = 0.0000101
# Epoch 33, Iteration 230, loss = 0.0822263
# Got 319 / 347 correct (91.93)
# Epoch 34, Iteration 0, loss = 0.0000093
# Epoch 34, Iteration 10, loss = 0.0038071
# Epoch 34, Iteration 20, loss = 0.1380626
# Epoch 34, Iteration 30, loss = 0.0031853
# Epoch 34, Iteration 40, loss = 0.1115249
# Epoch 34, Iteration 50, loss = 0.0006274
# Epoch 34, Iteration 60, loss = 0.0412845
# Epoch 34, Iteration 70, loss = 0.0000007
# Epoch 34, Iteration 80, loss = 0.2754290
# Epoch 34, Iteration 90, loss = 0.0003134
# Epoch 34, Iteration 100, loss = 0.0032404
# Epoch 34, Iteration 110, loss = 0.0000106
# Epoch 34, Iteration 120, loss = 0.0134972
# Epoch 34, Iteration 130, loss = 0.0186961
# Epoch 34, Iteration 140, loss = 0.0000161
# Epoch 34, Iteration 150, loss = 0.0000016
# Epoch 34, Iteration 160, loss = 0.0004334
# Epoch 34, Iteration 170, loss = 0.0000005
# Epoch 34, Iteration 180, loss = 0.0000010
# Epoch 34, Iteration 190, loss = 0.0000576
# Epoch 34, Iteration 200, loss = 0.0000128
# Epoch 34, Iteration 210, loss = 0.0000315
# Epoch 34, Iteration 220, loss = 0.0000086
# Epoch 34, Iteration 230, loss = 0.0000086
# Got 341 / 347 correct (98.27)
# Epoch 35, Iteration 0, loss = 0.0004864
# Epoch 35, Iteration 10, loss = 0.0000000
# Epoch 35, Iteration 20, loss = 0.0002254
# Epoch 35, Iteration 30, loss = 0.0000031
# Epoch 35, Iteration 40, loss = 0.0000003
# Epoch 35, Iteration 50, loss = 0.0000001
# Epoch 35, Iteration 60, loss = 0.0000530
# Epoch 35, Iteration 70, loss = 0.0007927
# Epoch 35, Iteration 80, loss = 0.0000025
# Epoch 35, Iteration 90, loss = 0.0032052
# Epoch 35, Iteration 100, loss = 0.0000582
# Epoch 35, Iteration 110, loss = 0.0008673
# Epoch 35, Iteration 120, loss = 0.0011610
# Epoch 35, Iteration 130, loss = 0.0000329
# Epoch 35, Iteration 140, loss = 0.0008924
# Epoch 35, Iteration 150, loss = 0.0000223
# Epoch 35, Iteration 160, loss = 0.2185100
# Epoch 35, Iteration 170, loss = 0.0000007
# Epoch 35, Iteration 180, loss = 0.7195551
# Epoch 35, Iteration 190, loss = 0.0000079
# Epoch 35, Iteration 200, loss = 0.0001916
# Epoch 35, Iteration 210, loss = 0.0000002
# Epoch 35, Iteration 220, loss = 1.0534954
# Epoch 35, Iteration 230, loss = 0.0000034
# Got 326 / 347 correct (93.95)
# Epoch 36, Iteration 0, loss = 0.0000074
# Epoch 36, Iteration 10, loss = 0.0000053
# Epoch 36, Iteration 20, loss = 0.0047266
# Epoch 36, Iteration 30, loss = 0.0024616
# Epoch 36, Iteration 40, loss = 0.0000005
# Epoch 36, Iteration 50, loss = 0.0151632
# Epoch 36, Iteration 60, loss = 0.0114114
# Epoch 36, Iteration 70, loss = 0.0716368
# Epoch 36, Iteration 80, loss = 0.0003619
# Epoch 36, Iteration 90, loss = 0.0001498
# Epoch 36, Iteration 100, loss = 0.0000022
# Epoch 36, Iteration 110, loss = 0.0061913
# Epoch 36, Iteration 120, loss = 0.0143801
# Epoch 36, Iteration 130, loss = 0.0125837
# Epoch 36, Iteration 140, loss = 0.0021855
# Epoch 36, Iteration 150, loss = 0.0025760
# Epoch 36, Iteration 160, loss = 0.0000002
# Epoch 36, Iteration 170, loss = 0.0073347
# Epoch 36, Iteration 180, loss = 0.0212576
# Epoch 36, Iteration 190, loss = 0.0000432
# Epoch 36, Iteration 200, loss = 0.0001186
# Epoch 36, Iteration 210, loss = 0.0000474
# Epoch 36, Iteration 220, loss = 0.0000004
# Epoch 36, Iteration 230, loss = 0.0000000
# Got 338 / 347 correct (97.41)
# Epoch 37, Iteration 0, loss = 0.0018518
# Epoch 37, Iteration 10, loss = 0.2710136
# Epoch 37, Iteration 20, loss = 0.0005608
# Epoch 37, Iteration 30, loss = 0.1608082
# Epoch 37, Iteration 40, loss = 0.0062167
# Epoch 37, Iteration 50, loss = 0.3436717
# Epoch 37, Iteration 60, loss = 0.0050657
# Epoch 37, Iteration 70, loss = 0.0000348
# Epoch 37, Iteration 80, loss = 0.0005136
# Epoch 37, Iteration 90, loss = 0.0034742
# Epoch 37, Iteration 100, loss = 0.0000216
# Epoch 37, Iteration 110, loss = 0.0006519
# Epoch 37, Iteration 120, loss = 0.0000006
# Epoch 37, Iteration 130, loss = 0.0000881
# Epoch 37, Iteration 140, loss = 0.0000096
# Epoch 37, Iteration 150, loss = 0.0000005
# Epoch 37, Iteration 160, loss = 0.0075275
# Epoch 37, Iteration 170, loss = 0.0026161
# Epoch 37, Iteration 180, loss = 0.0013530
# Epoch 37, Iteration 190, loss = 0.0000005
# Epoch 37, Iteration 200, loss = 0.0038764
# Epoch 37, Iteration 210, loss = 0.3734571
# Epoch 37, Iteration 220, loss = 0.4331175
# Epoch 37, Iteration 230, loss = 0.0000235
# Got 326 / 347 correct (93.95)
# Epoch 38, Iteration 0, loss = 0.8103756
# Epoch 38, Iteration 10, loss = 0.0000073
# Epoch 38, Iteration 20, loss = 0.0015974
# Epoch 38, Iteration 30, loss = 0.0053476
# Epoch 38, Iteration 40, loss = 0.1687453
# Epoch 38, Iteration 50, loss = 0.0002775
# Epoch 38, Iteration 60, loss = 0.0001608
# Epoch 38, Iteration 70, loss = 0.0000000
# Epoch 38, Iteration 80, loss = 0.0000007
# Epoch 38, Iteration 90, loss = 0.1226088
# Epoch 38, Iteration 100, loss = 0.0000008
# Epoch 38, Iteration 110, loss = 0.0070206
# Epoch 38, Iteration 120, loss = 0.0006991
# Epoch 38, Iteration 130, loss = 0.0000002
# Epoch 38, Iteration 140, loss = 0.0022590
# Epoch 38, Iteration 150, loss = 0.0223770
# Epoch 38, Iteration 160, loss = 0.0000006
# Epoch 38, Iteration 170, loss = 0.0000035
# Epoch 38, Iteration 180, loss = 0.0022615
# Epoch 38, Iteration 190, loss = 0.0000025
# Epoch 38, Iteration 200, loss = 0.0000447
# Epoch 38, Iteration 210, loss = 0.0033340
# Epoch 38, Iteration 220, loss = 0.0026104
# Epoch 38, Iteration 230, loss = 0.0000021
# Got 335 / 347 correct (96.54)
# Epoch 39, Iteration 0, loss = 0.0232179
# Epoch 39, Iteration 10, loss = 0.0000000
# Epoch 39, Iteration 20, loss = 0.0000061
# Epoch 39, Iteration 30, loss = 0.0198619
# Epoch 39, Iteration 40, loss = 0.0009395
# Epoch 39, Iteration 50, loss = 0.0013636
# Epoch 39, Iteration 60, loss = 0.0000004
# Epoch 39, Iteration 70, loss = 0.0000053
# Epoch 39, Iteration 80, loss = 0.0027923
# Epoch 39, Iteration 90, loss = 0.0000021
# Epoch 39, Iteration 100, loss = 0.0000056
# Epoch 39, Iteration 110, loss = 0.0001103
# Epoch 39, Iteration 120, loss = 0.0000000
# Epoch 39, Iteration 130, loss = 0.0000001
# Epoch 39, Iteration 140, loss = 0.0472834
# Epoch 39, Iteration 150, loss = 0.0000006
# Epoch 39, Iteration 160, loss = 0.0814578
# Epoch 39, Iteration 170, loss = 0.0022850
# Epoch 39, Iteration 180, loss = 0.0000051
# Epoch 39, Iteration 190, loss = 0.0066151
# Epoch 39, Iteration 200, loss = 0.0000017
# Epoch 39, Iteration 210, loss = 0.0000002
# Epoch 39, Iteration 220, loss = 0.0000118
# Epoch 39, Iteration 230, loss = 0.0000000
# Got 336 / 347 correct (96.83)
# Epoch 40, Iteration 0, loss = 0.0000143
# Epoch 40, Iteration 10, loss = 0.0000000
# Epoch 40, Iteration 20, loss = 0.0059060
# Epoch 40, Iteration 30, loss = 0.0000239
# Epoch 40, Iteration 40, loss = 0.0004964
# Epoch 40, Iteration 50, loss = 0.0010249
# Epoch 40, Iteration 60, loss = 0.0003649
# Epoch 40, Iteration 70, loss = 0.0030361
# Epoch 40, Iteration 80, loss = 0.0000063
# Epoch 40, Iteration 90, loss = 0.1398702
# Epoch 40, Iteration 100, loss = 0.0002746
# Epoch 40, Iteration 110, loss = 0.0000565
# Epoch 40, Iteration 120, loss = 0.1676050
# Epoch 40, Iteration 130, loss = 0.0000016
# Epoch 40, Iteration 140, loss = 0.0042591
# Epoch 40, Iteration 150, loss = 0.0000023
# Epoch 40, Iteration 160, loss = 0.0000024
# Epoch 40, Iteration 170, loss = 0.0000000
# Epoch 40, Iteration 180, loss = 0.0000006
# Epoch 40, Iteration 190, loss = 0.0018506
# Epoch 40, Iteration 200, loss = 0.0000014
# Epoch 40, Iteration 210, loss = 0.0000000
# Epoch 40, Iteration 220, loss = 0.0014594
# Epoch 40, Iteration 230, loss = 0.0000227
# Got 329 / 347 correct (94.81)
# Epoch 41, Iteration 0, loss = 0.0000025
# Epoch 41, Iteration 10, loss = 0.0000051
# Epoch 41, Iteration 20, loss = 0.0011715
# Epoch 41, Iteration 30, loss = 0.0002086
# Epoch 41, Iteration 40, loss = 0.1468660
# Epoch 41, Iteration 50, loss = 0.0001150
# Epoch 41, Iteration 60, loss = 0.0004919
# Epoch 41, Iteration 70, loss = 0.0038271
# Epoch 41, Iteration 80, loss = 0.0000017
# Epoch 41, Iteration 90, loss = 0.0000087
# Epoch 41, Iteration 100, loss = 0.0000014
# Epoch 41, Iteration 110, loss = 0.0000000
# Epoch 41, Iteration 120, loss = 0.0000012
# Epoch 41, Iteration 130, loss = 0.0128190
# Epoch 41, Iteration 140, loss = 0.0002468
# Epoch 41, Iteration 150, loss = 0.0000278
# Epoch 41, Iteration 160, loss = 0.1663748
# Epoch 41, Iteration 170, loss = 0.0000643
# Epoch 41, Iteration 180, loss = 0.0004579
# Epoch 41, Iteration 190, loss = 0.0000010
# Epoch 41, Iteration 200, loss = 0.0000002
# Epoch 41, Iteration 210, loss = 0.0000107
# Epoch 41, Iteration 220, loss = 0.0126947
# Epoch 41, Iteration 230, loss = 0.0057754
# Got 327 / 347 correct (94.24)
# Epoch 42, Iteration 0, loss = 0.0088894
# Epoch 42, Iteration 10, loss = 0.0000659
# Epoch 42, Iteration 20, loss = 0.0000017
# Epoch 42, Iteration 30, loss = 0.0000000
# Epoch 42, Iteration 40, loss = 0.0000000
# Epoch 42, Iteration 50, loss = 0.1153470
# Epoch 42, Iteration 60, loss = 0.0000005
# Epoch 42, Iteration 70, loss = 0.0000003
# Epoch 42, Iteration 80, loss = 0.0253599
# Epoch 42, Iteration 90, loss = 0.0000015
# Epoch 42, Iteration 100, loss = 0.3685732
# Epoch 42, Iteration 110, loss = 0.0912669
# Epoch 42, Iteration 120, loss = 0.0006096
# Epoch 42, Iteration 130, loss = 0.0015672
# Epoch 42, Iteration 140, loss = 0.0004018
# Epoch 42, Iteration 150, loss = 0.0000987
# Epoch 42, Iteration 160, loss = 0.0000002
# Epoch 42, Iteration 170, loss = 0.0005789
# Epoch 42, Iteration 180, loss = 0.0005068
# Epoch 42, Iteration 190, loss = 0.0000014
# Epoch 42, Iteration 200, loss = 0.0019889
# Epoch 42, Iteration 210, loss = 0.0000000
# Epoch 42, Iteration 220, loss = 0.0000520
# Epoch 42, Iteration 230, loss = 0.0000003
# Got 332 / 347 correct (95.68)
# Epoch 43, Iteration 0, loss = 0.0000000
# Epoch 43, Iteration 10, loss = 0.0004018
# Epoch 43, Iteration 20, loss = 0.0000327
# Epoch 43, Iteration 30, loss = 0.0000067
# Epoch 43, Iteration 40, loss = 0.0000038
# Epoch 43, Iteration 50, loss = 0.0000168
# Epoch 43, Iteration 60, loss = 0.0013540
# Epoch 43, Iteration 70, loss = 0.0000000
# Epoch 43, Iteration 80, loss = 0.0001612
# Epoch 43, Iteration 90, loss = 0.0000542
# Epoch 43, Iteration 100, loss = 0.0000000
# Epoch 43, Iteration 110, loss = 0.0000000
# Epoch 43, Iteration 120, loss = 0.0000095
# Epoch 43, Iteration 130, loss = 0.0000108
# Epoch 43, Iteration 140, loss = 0.0002324
# Epoch 43, Iteration 150, loss = 0.0000000
# Epoch 43, Iteration 160, loss = 0.0436104
# Epoch 43, Iteration 170, loss = 0.0043957
# Epoch 43, Iteration 180, loss = 0.0176969
# Epoch 43, Iteration 190, loss = 0.0249599
# Epoch 43, Iteration 200, loss = 0.0000149
# Epoch 43, Iteration 210, loss = 0.0000041
# Epoch 43, Iteration 220, loss = 0.0003430
# Epoch 43, Iteration 230, loss = 0.0000080
# Got 324 / 347 correct (93.37)
# Epoch 44, Iteration 0, loss = 0.0000000
# Epoch 44, Iteration 10, loss = 0.0106622
# Epoch 44, Iteration 20, loss = 0.0003168
# Epoch 44, Iteration 30, loss = 0.0000000
# Epoch 44, Iteration 40, loss = 0.0001875
# Epoch 44, Iteration 50, loss = 0.0000002
# Epoch 44, Iteration 60, loss = 0.0001245
# Epoch 44, Iteration 70, loss = 0.0000072
# Epoch 44, Iteration 80, loss = 0.0000280
# Epoch 44, Iteration 90, loss = 0.0000061
# Epoch 44, Iteration 100, loss = 0.0595067
# Epoch 44, Iteration 110, loss = 0.0049465
# Epoch 44, Iteration 120, loss = 0.0004969
# Epoch 44, Iteration 130, loss = 0.0138852
# Epoch 44, Iteration 140, loss = 0.0004355
# Epoch 44, Iteration 150, loss = 0.0000005
# Epoch 44, Iteration 160, loss = 0.0000006
# Epoch 44, Iteration 170, loss = 0.0002810
# Epoch 44, Iteration 180, loss = 0.0000942
# Epoch 44, Iteration 190, loss = 0.0000000
# Epoch 44, Iteration 200, loss = 0.0000011
# Epoch 44, Iteration 210, loss = 0.0000000
# Epoch 44, Iteration 220, loss = 0.0000133
# Epoch 44, Iteration 230, loss = 0.0000242
# Got 337 / 347 correct (97.12)
# Epoch 45, Iteration 0, loss = 0.0000835
# Epoch 45, Iteration 10, loss = 0.0000000
# Epoch 45, Iteration 20, loss = 0.0000002
# Epoch 45, Iteration 30, loss = 0.0000000
# Epoch 45, Iteration 40, loss = 0.0052507
# Epoch 45, Iteration 50, loss = 0.0003896
# Epoch 45, Iteration 60, loss = 0.3387572
# Epoch 45, Iteration 70, loss = 0.0000058
# Epoch 45, Iteration 80, loss = 0.0008361
# Epoch 45, Iteration 90, loss = 0.0000068
# Epoch 45, Iteration 100, loss = 0.0000182
# Epoch 45, Iteration 110, loss = 0.0000002
# Epoch 45, Iteration 120, loss = 0.0001805
# Epoch 45, Iteration 130, loss = 0.0024345
# Epoch 45, Iteration 140, loss = 0.0000236
# Epoch 45, Iteration 150, loss = 0.0000000
# Epoch 45, Iteration 160, loss = 0.0000105
# Epoch 45, Iteration 170, loss = 0.0000002
# Epoch 45, Iteration 180, loss = 0.0000043
# Epoch 45, Iteration 190, loss = 0.0001694
# Epoch 45, Iteration 200, loss = 0.0022334
# Epoch 45, Iteration 210, loss = 0.0000155
# Epoch 45, Iteration 220, loss = 0.0000021
# Epoch 45, Iteration 230, loss = 0.0000022
# Got 339 / 347 correct (97.69)
# Epoch 46, Iteration 0, loss = 0.0000078
# Epoch 46, Iteration 10, loss = 0.0005647
# Epoch 46, Iteration 20, loss = 0.0013032
# Epoch 46, Iteration 30, loss = 0.0001210
# Epoch 46, Iteration 40, loss = 0.0000039
# Epoch 46, Iteration 50, loss = 0.0000000
# Epoch 46, Iteration 60, loss = 0.0000001
# Epoch 46, Iteration 70, loss = 0.0000022
# Epoch 46, Iteration 80, loss = 0.0001055
# Epoch 46, Iteration 90, loss = 0.0000784
# Epoch 46, Iteration 100, loss = 0.0000030
# Epoch 46, Iteration 110, loss = 0.0000002
# Epoch 46, Iteration 120, loss = 0.0000000
# Epoch 46, Iteration 130, loss = 0.0000018
# Epoch 46, Iteration 140, loss = 0.0009620
# Epoch 46, Iteration 150, loss = 0.0000000
# Epoch 46, Iteration 160, loss = 0.0001666
# Epoch 46, Iteration 170, loss = 0.0000000
# Epoch 46, Iteration 180, loss = 0.0000009
# Epoch 46, Iteration 190, loss = 0.0000685
# Epoch 46, Iteration 200, loss = 0.0000008
# Epoch 46, Iteration 210, loss = 0.0023292
# Epoch 46, Iteration 220, loss = 0.0000165
# Epoch 46, Iteration 230, loss = 0.0056450
# Got 340 / 347 correct (97.98)
# Epoch 47, Iteration 0, loss = 0.0000006
# Epoch 47, Iteration 10, loss = 0.0000000
# Epoch 47, Iteration 20, loss = 0.0000001
# Epoch 47, Iteration 30, loss = 0.0004295
# Epoch 47, Iteration 40, loss = 0.0000016
# Epoch 47, Iteration 50, loss = 0.0000000
# Epoch 47, Iteration 60, loss = 0.0000009
# Epoch 47, Iteration 70, loss = 0.0000008
# Epoch 47, Iteration 80, loss = 0.0000220
# Epoch 47, Iteration 90, loss = 0.0000237
# Epoch 47, Iteration 100, loss = 0.0000000
# Epoch 47, Iteration 110, loss = 0.0000002
# Epoch 47, Iteration 120, loss = 0.0000180
# Epoch 47, Iteration 130, loss = 0.0004778
# Epoch 47, Iteration 140, loss = 0.0000043
# Epoch 47, Iteration 150, loss = 0.0000000
# Epoch 47, Iteration 160, loss = 0.0000126
# Epoch 47, Iteration 170, loss = 0.0276217
# Epoch 47, Iteration 180, loss = 0.0000401
# Epoch 47, Iteration 190, loss = 0.0000054
# Epoch 47, Iteration 200, loss = 0.0006928
# Epoch 47, Iteration 210, loss = 0.0000475
# Epoch 47, Iteration 220, loss = 0.0000695
# Epoch 47, Iteration 230, loss = 0.0000008
# Got 336 / 347 correct (96.83)
# Epoch 48, Iteration 0, loss = 0.0006430
# Epoch 48, Iteration 10, loss = 0.0000046
# Epoch 48, Iteration 20, loss = 0.0014249
# Epoch 48, Iteration 30, loss = 0.0014791
# Epoch 48, Iteration 40, loss = 0.1888744
# Epoch 48, Iteration 50, loss = 0.0000007
# Epoch 48, Iteration 60, loss = 0.0000613
# Epoch 48, Iteration 70, loss = 0.0000000
# Epoch 48, Iteration 80, loss = 0.3330876
# Epoch 48, Iteration 90, loss = 0.0004246
# Epoch 48, Iteration 100, loss = 0.0000057
# Epoch 48, Iteration 110, loss = 0.0073375
# Epoch 48, Iteration 120, loss = 0.7860518
# Epoch 48, Iteration 130, loss = 0.0596895
# Epoch 48, Iteration 140, loss = 0.0056225
# Epoch 48, Iteration 150, loss = 0.0006007
# Epoch 48, Iteration 160, loss = 0.0000000
# Epoch 48, Iteration 170, loss = 0.0158286
# Epoch 48, Iteration 180, loss = 0.0000003
# Epoch 48, Iteration 190, loss = 0.0000045
# Epoch 48, Iteration 200, loss = 0.0033820
# Epoch 48, Iteration 210, loss = 0.0000003
# Epoch 48, Iteration 220, loss = 0.0015915
# Epoch 48, Iteration 230, loss = 0.0062652
# Got 334 / 347 correct (96.25)
# Epoch 49, Iteration 0, loss = 0.0002481
# Epoch 49, Iteration 10, loss = 0.0000811
# Epoch 49, Iteration 20, loss = 0.0018334
# Epoch 49, Iteration 30, loss = 0.0002618
# Epoch 49, Iteration 40, loss = 0.0000566
# Epoch 49, Iteration 50, loss = 0.0000003
# Epoch 49, Iteration 60, loss = 0.0000186
# Epoch 49, Iteration 70, loss = 0.0000000
# Epoch 49, Iteration 80, loss = 0.0000028
# Epoch 49, Iteration 90, loss = 0.1362381
# Epoch 49, Iteration 100, loss = 0.0012157
# Epoch 49, Iteration 110, loss = 0.0000021
# Epoch 49, Iteration 120, loss = 0.0272797
# Epoch 49, Iteration 130, loss = 0.0000004
# Epoch 49, Iteration 140, loss = 0.0000012
# Epoch 49, Iteration 150, loss = 0.0000002
# Epoch 49, Iteration 160, loss = 0.0000216
# Epoch 49, Iteration 170, loss = 0.0000078
# Epoch 49, Iteration 180, loss = 0.0000864
# Epoch 49, Iteration 190, loss = 0.0000607
# Epoch 49, Iteration 200, loss = 0.2478308
# Epoch 49, Iteration 210, loss = 0.0000000
# Epoch 49, Iteration 220, loss = 0.0004955
# Epoch 49, Iteration 230, loss = 0.0000837
# Got 339 / 347 correct (97.69)

# %%
# test set accuracy
check_accuracy(loader_test, model)
# Out:
# Got 339 / 347 correct (97.69)
# (0.9769452449567724, tensor(0.0270, device='cuda:0'))

# %% [markdown]
# ## Try getting Pre-trained Model

# %%
import torch
model = torch.hub.load('pytorch/vision:v0.8.2', 'alexnet', pretrained=True)
model.eval()

# if torch.cuda.is_available():
#     train_data = train_data#.to('cuda')
#     model.to('cuda')
for t, data in enumerate(loader_train): 
    with torch.no_grad():
        output = model()
    # Tensor of shape 1000, with confidence scores over Imagenet's 1000 classes
    print(output[0])
    # The output has unnormalized scores. To get probabilities, you can run a softmax on it.
    probabilities = torch.nn.functional.softmax(output[0], dim=0)
    print(probabilities)

# %%
# import torchvision
# vgg19 = torchvision.models.vgg19(pretrained=True)

# vgg19.classifier[1] = nn.Conv2d(vgg19.classifier[1].in_channels,5,1,1)

from torchvision import datasets, models, transforms
 
squeezenet = models.squeezenet1_1(pretrained=True, progress=True)
# Replace the last layer with one with the correct number of channels
network.load_state_dict
num_ftr = squeezenet.classifier[1].in_channels
squeezenet.classifier[1] = nn.Conv2d(num_ftr, 5, 1, 1)
# squeezenet

# %%
from keras.applications.vgg16 import VGG16
model = VGG16()

from keras.applications.vgg16 import preprocess_input
# prepare the image for the VGG model
image = preprocess_input(image)

# predict the probability across all output classes
yhat = model.predict(image)

# %%
def test(neutral_faces, smiling_faces, eyesclosed_faces, surprised_faces, sunglasses_faces, n): 
# def test(neutral_faces,smiling_faces,eyesclosed_faces, n): 
    '''
    Function to test that I am able to recontruct the original image with after all the reshaping and shaping.
    Checking the dimensions and shape as well. 
    '''
    print(neutral_faces.shape)

    plt.subplot(1,5,1)
    plt.imshow((neutral_faces[:,n]).reshape((224,224)))
    plt.subplot(1,5,2)
    plt.imshow((smiling_faces[:,n]).reshape((224,224)))
    plt.subplot(1,5,3)
    plt.imshow((eyesclosed_faces[:,n]).reshape((224,224)))
    plt.subplot(1,5,4)
    plt.imshow((surprised_faces[:,n]).reshape((224,224)))
    plt.subplot(1,5,5)
    plt.imshow((sunglasses_faces[:,n]).reshape((224,224)))

# Executing test function        
# test(neutral_faces, smiling_faces, eyesclosed_faces, surprised_faces, sunglasses_faces, 25)

# %% [markdown]
# 5/27 to do next:
# - need dataloader
# - figure out if data is already centered (if not, how to do it for PCA)
# - feature extraction (PCA)
# - train our ELMAN RNN (link for how to use RNN with Pytorch: https://www.kaggle.com/kanncaa1/recurrent-neural-network-with-pytorch, https://pytorch.org/docs/stable/generated/torch.nn.RNN.html)
# - find optimal weights
# - test
# - try out other types of netral networks

# %% [markdown]
# Reference* Any publication using this database must reference to this:
# - Website: http://tdface.ece.tufts.edu/ and this
# - Paper: Panetta, Karen, Qianwen Wan, Sos Agaian, Srijith Rajeev, Shreyas Kamath, Rahul Rajendran, Shishir Rao et al. "A comprehensive database for benchmarking imaging systems." IEEE Transactions on Pattern Analysis and Machine Intelligence (2018).
# - R Vemulapalli, A Agarwala, “A Compact Embedding for Facial Expression Similarity”, CoRR, abs/1811.11283, 2018.
